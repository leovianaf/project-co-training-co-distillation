# %% [markdown]
# ## Download dos Datasets utilizados no paper
# - BookCorpus
# - Wikipedia (11/2023)

# %%
from datasets import load_dataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from datasets import load_dataset
#
# ModuleNotFoundError: No module named 'datasets'

# %%
# BookCorpus disponível no Hugging Face Hub
bookcorpus_ds = load_dataset("rojagtap/bookcorpus")
print("BookCorpus baixado com sucesso!")
print(bookcorpus_ds)

# Download da Wikipedia (pesado), versão de Novembro de 2023
wiki_ds = load_dataset("wikimedia/wikipedia", "20231101.en")
print("Wikipedia baixada com sucesso!")
print(wiki_ds)


print("\n--- Exemplo de dado do BookCorpus ---")
print(bookcorpus_ds['train'][0])

print("\n--- Exemplo de dado da Wikipedia ---")
print(wiki_ds['train'][0])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from datasets import load_dataset
#       3 print("Iniciando o download dos datasets...")
#       5 # --- 1. Baixando o BookCorpus ---
#       6 # Esta é uma versão disponível no Hugging Face Hub
#
# ModuleNotFoundError: No module named 'datasets'
